# %%
path1 = "/Users/asharifi/Desktop/nba-players-stats 2/Seasons_Stats.csv"
path2 = "/Users/asharifi/Desktop/nba-players-stats 2/nba_salaries_1990_to_2018.csv"

# %%
import pandas as pd

# %%
df1 = pd.read_csv(path1)

# %%
df2 = pd.read_csv(path2)

# %%
df1
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# 5               5  1950.0         Ed Bartels    F  24.0  NYK   2.0   NaN
# 6               6  1950.0        Ralph Beard    G  22.0  INO  60.0   NaN
# 7               7  1950.0         Gene Berce  G-F  23.0  TRI   3.0   NaN
# 8               8  1950.0      Charlie Black  F-C  28.0  TOT  65.0   NaN
# 9               9  1950.0      Charlie Black  F-C  28.0  FTW  36.0   NaN
# 10             10  1950.0      Charlie Black  F-C  28.0  AND  29.0   NaN
# 11             11  1950.0        Nelson Bobb   PG  25.0  PHW  57.0   NaN
# ...

# %%
df2
# Out:
#                   player    salary  season_end  season_start team  \
# 0           Moses Malone   2406000        1991          1990  ATL
# 1      Dominique Wilkins   2065000        1991          1990  ATL
# 2             Jon Koncak   1550000        1991          1990  ATL
# 3             Doc Rivers    895000        1991          1990  ATL
# 4        Rumeal Robinson    800000        1991          1990  ATL
# 5          Tim McCormick    775000        1991          1990  ATL
# 6           Kevin Willis    685000        1991          1990  ATL
# 7       Alexander Volkov    650000        1991          1990  ATL
# 8            John Battle    590000        1991          1990  ATL
# 9        Sidney Moncrief    510000        1991          1990  ATL
# 10             Spud Webb    510000        1991          1990  ATL
# 11          Gary Leonard    200000        1991          1990  ATL
# 12         Duane Ferrell    125000        1991          1990  ATL
# ...

# %%
df2.columns
# Out:
# Index(['player', 'salary', 'season_end', 'season_start', 'team', 'team_name'], dtype='object')

# %%
#rename columns to help with merge
df2.columns = ['Player', 'salary', 'season_end', 'season_start', 'team', 'team_name']

# %%
#filter dataset to match with the salary content
df1 = df1.loc[(df1['Year'] >= 1990)]

# %%
#merge datasets
df3 = pd.merge(df1, df2)

# %%
df3
# Out:
#         Unnamed: 0    Year                 Player Pos   Age   Tm     G    GS  \
# 0             9547  1990.0             Mark Acres   C  27.0  ORL  80.0  50.0
# 1             9547  1990.0             Mark Acres   C  27.0  ORL  80.0  50.0
# 2            10009  1991.0             Mark Acres   C  28.0  ORL  68.0   0.0
# 3            10009  1991.0             Mark Acres   C  28.0  ORL  68.0   0.0
# 4            10451  1992.0             Mark Acres   C  29.0  ORL  68.0   6.0
# 5            10451  1992.0             Mark Acres   C  29.0  ORL  68.0   6.0
# 6            10912  1993.0             Mark Acres   C  30.0  TOT  18.0   7.0
# 7            10912  1993.0             Mark Acres   C  30.0  TOT  18.0   7.0
# 8            10913  1993.0             Mark Acres   C  30.0  HOU   6.0   0.0
# 9            10913  1993.0             Mark Acres   C  30.0  HOU   6.0   0.0
# 10           10914  1993.0             Mark Acres   C  30.0  WSB  12.0   7.0
# ...

# %%
df3.head(10)
# Out:
#    Unnamed: 0    Year      Player Pos   Age   Tm     G    GS      MP   PER  \
# 0        9547  1990.0  Mark Acres   C  27.0  ORL  80.0  50.0  1691.0   8.3
# 1        9547  1990.0  Mark Acres   C  27.0  ORL  80.0  50.0  1691.0   8.3
# 2       10009  1991.0  Mark Acres   C  28.0  ORL  68.0   0.0  1313.0   9.2
# 3       10009  1991.0  Mark Acres   C  28.0  ORL  68.0   0.0  1313.0   9.2
# 4       10451  1992.0  Mark Acres   C  29.0  ORL  68.0   6.0   926.0  10.1
# 5       10451  1992.0  Mark Acres   C  29.0  ORL  68.0   6.0   926.0  10.1
# 6       10912  1993.0  Mark Acres   C  30.0  TOT  18.0   7.0   269.0   8.9
# 7       10912  1993.0  Mark Acres   C  30.0  TOT  18.0   7.0   269.0   8.9
# 8       10913  1993.0  Mark Acres   C  30.0  HOU   6.0   0.0    23.0  -0.6
# 9       10913  1993.0  Mark Acres   C  30.0  HOU   6.0   0.0    23.0  -0.6
#
#    ...   STL   BLK   TOV     PF    PTS  salary  season_end  season_start  \
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'salary', 'season_end',
#        'season_start', 'team', 'team_name'],
#       dtype='object')

# %%
df3.boxplot(column='salary')

# %%
import numpy as np

# %%
df3_num = np.asarray(df3['salary'])

# %%
df3_num
# Out:
# array([ 437000,  547000,  437000, ..., 1312611, 1034956, 1312611])

# %%
df3_num.mean()
# Out:
# 4026064.0103105786

# %%
df3.sort_values(by='salary', ascending=False)
# Out:
#         Unnamed: 0    Year          Player Pos   Age   Tm     G    GS      MP  \
# 108397       23633  2016.0   Stephen Curry  PG  27.0  GSW  79.0  79.0  2700.0
# 108370       21798  2013.0   Stephen Curry  PG  24.0  GSW  78.0  78.0  2983.0
# 108352       20654  2011.0   Stephen Curry  PG  22.0  GSW  74.0  74.0  2489.0
# 108343       20042  2010.0   Stephen Curry  PG  21.0  GSW  80.0  77.0  2896.0
# 108361       21236  2012.0   Stephen Curry  PG  23.0  GSW  26.0  23.0   732.0
# 108388       23000  2015.0   Stephen Curry  PG  26.0  GSW  80.0  80.0  2613.0
# 108406       24216  2017.0   Stephen Curry  PG  28.0  GSW  79.0  79.0  2638.0
# 108379       22402  2014.0   Stephen Curry  PG  25.0  GSW  78.0  78.0  2846.0
# 84779        21933  2013.0    LeBron James  PF  28.0  MIA  76.0  76.0  2877.0
# 84765        21395  2012.0    LeBron James  SF  27.0  MIA  62.0  62.0  2326.0
# 84807        23154  2015.0    LeBron James  SF  30.0  CLE  69.0  69.0  2493.0
# ...

# %%
#lets look at stephan curry stats
#how about three point shooting over all seasons
steph_curry = df3.loc[(df3['Player'] == 'Stephen Curry')]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
#sns.lineplot(x=steph_curry['Year'], y = steph_curry['3P'])
sns.set()

# %%
sns.barplot(x = steph_curry['Year'], y=steph_curry['3P'])

# %%
df3.Age.describe()
# Out:
# count    118907.000000
# mean         27.535477
# std           4.260561
# min          18.000000
# 25%          24.000000
# 50%          27.000000
# 75%          31.000000
# max          44.000000
# Name: Age, dtype: float64

# %%
df3.Age.plot.hist()

# %%
df3.salary.value_counts().head(10).plot.bar()

# %%
df3['salary'].value_counts().sort_index().plot.line()

# %%
df3_post_2010 = df3.loc[(df3['Year'] > 2009)]

# %%
df3_post_2010['salary'].value_counts().sort_index().plot.area()

# %%
df3_post_2010[df3_post_2010['salary']>10000000].plot.scatter(x='salary', y='MP', c = 'PTS', colormap = 'viridis')

# %%
df3_post_2010.plot.hexbin(x='salary', y='MP', gridsize=15)

# %%
df3_post_2010[df3_post_2010['PF'] > 100].plot.hexbin(x='salary', y='MP', gridsize=15)

# %%
sns.countplot(df3_post_2010['salary'])

# %%
sns.distplot(df3_post_2010['PF'], bins = 5)
# Out:
# /Users/asharifi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
df3_post_2010_pf = df3_post_2010.loc[(df3_post_2010['PF'] > 250)]

# %%
df3_post_2010_pf.describe()
# Out:
#          Unnamed: 0         Year         Age           G          GS  \
# count    486.000000   486.000000  486.000000  486.000000  486.000000
# mean   21467.088477  2012.181070   24.621399   78.971193   66.915638
# std     1277.865923     2.150074    2.686483    3.776650   19.164053
# min    19983.000000  2010.000000   19.000000   64.000000    5.000000
# 25%    20254.000000  2010.000000   22.000000   77.000000   62.000000
# 50%    20842.000000  2011.000000   25.000000   81.000000   76.000000
# 75%    22524.000000  2014.000000   27.000000   82.000000   80.000000
# max    24630.000000  2017.000000   32.000000   82.000000   82.000000
#
#                 MP         PER         TS%        3PAr         FTr  ...  \
# count   486.000000  486.000000  486.000000  486.000000  486.000000  ...
# mean   2413.561728   17.852058    0.564259    0.083675    0.404792  ...
# std     377.035249    3.789087    0.042576    0.154897    0.197495  ...
# ...

# %%
df3_post_2010_pf.plot.scatter(x='PF', y = 'MP')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
