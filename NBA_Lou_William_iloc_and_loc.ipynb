# %%
path = "/Users/asharifi/Desktop/nba-players-stats 2/Seasons_Stats.csv"

# %%
import pandas as pd
from pandas import DataFrame

# %%
import numpy as np

# %%
data = pd.read_csv(path, na_values='NaN')

# %%
new_cut = data.iloc[:2, :4]

# %%
new_cut
# Out:
#    Unnamed: 0    Year           Player  Pos
# 0           0  1950.0  Curly Armstrong  G-F
# 1           1  1950.0     Cliff Barker   SG

# %%
new_cut.loc[1]
# Out:
# Unnamed: 0               1
# Year                  1950
# Player        Cliff Barker
# Pos                     SG
# Name: 1, dtype: object

# %%
type(new_cut.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
new_cut_iter = iter(new_cut)

# %%
new_cut_iter

# %%
data.iloc[-10:, 2:15]
# Out:
#                   Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 24681       Delon Wright  PG  24.0  TOR  27.0   0.0   446.0  15.0  0.535
# 24682        James Young  SG  21.0  BOS  29.0   0.0   220.0  10.0  0.549
# 24683          Joe Young  PG  24.0  IND  33.0   0.0   135.0  11.4  0.433
# 24684         Nick Young  SG  31.0  LAL  60.0  60.0  1556.0  14.1  0.588
# 24685     Thaddeus Young  PF  28.0  IND  74.0  74.0  2237.0  14.9  0.562
# 24686        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7  0.604
# 24687       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0  0.508
# 24688  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3  0.346
# 24689        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9  0.503
# 24690        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0  0.547
#
#         3PAr    FTr  ORB%  DRB%
# 24681  0.259  0.474   4.1   8.1
# 24682  0.603  0.155   3.1  10.0
# 24683  0.319  0.208   0.8  13.1
# 24684  0.665  0.142   1.7   8.2
# ...

# %%
lou_williams_stats = data.loc[(data['Player'] == 'Lou Williams')]

# %%
lou_williams_stats.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
lou_williams_stats_slice = lou_williams_stats.iloc[:, 6:15]

# %%
lou_williams_stats_slice.agg(['sum', 'min', 'mean', 'max'])
# Out:
#                G    GS            MP         PER       TS%      3PAr  \
# sum   863.000000  91.0  20430.000000  242.300000  7.682000  4.950000
# min    23.000000   0.0    145.000000    9.000000  0.485000  0.173000
# mean   61.642857   6.5   1459.285714   17.307143  0.548714  0.353571
# max    81.000000  38.0   2016.000000   23.900000  0.609000  0.489000
#
#            FTr  ORB%        DRB%
# sum   5.722000  25.2  126.300000
# min   0.250000   0.8    7.300000
# mean  0.408714   1.8    9.021429
# max   0.612000   3.0   12.900000

# %%
lou_williams_stats.boxplot(column= ['STL', 'AST', '3P', 'TOV'])

# %%
lou_williams_stats.iat[1,6] = 61.0

# %%
lou_williams_stats.iat[1,6]
# Out:
# 61.0

# %%
data_ast = data.loc[(data['AST'] >= 400) & (data['Year'] >= 2010)]

# %%
data_ast
# Out:
#        Unnamed: 0    Year                 Player    Pos   Age   Tm     G  \
# 19973       19973  2010.0       Chauncey Billups     PG  33.0  DEN  73.0
# 19996       19996  2010.0           Aaron Brooks     PG  25.0  HOU  82.0
# 20014       20014  2010.0          Jose Calderon     PG  28.0  TOR  68.0
# 20032       20032  2010.0        Darren Collison     PG  22.0  NOH  76.0
# 20034       20034  2010.0            Mike Conley     PG  22.0  MEM  80.0
# 20042       20042  2010.0          Stephen Curry     PG  21.0  GSW  80.0
# 20046       20046  2010.0            Baron Davis     PG  30.0  LAC  75.0
# 20079       20079  2010.0           Tyreke Evans     SG  20.0  SAC  72.0
# 20081       20081  2010.0         Raymond Felton     PG  25.0  CHA  80.0
# 20135       20135  2010.0           Devin Harris     PG  26.0  NJN  64.0
# 20186       20186  2010.0         Andre Iguodala     SF  26.0  PHI  82.0
# 20196       20196  2010.0           Jarrett Jack     PG  26.0  TOR  82.0
# ...

# %%
data_ast.size
# Out:
# 9328

# %%
data_ast.describe()
# Out:
#          Unnamed: 0         Year         Age           G          GS  \
# count    176.000000   176.000000  176.000000  176.000000  176.000000
# mean   22327.948864  2013.511364   26.238636   74.267045   69.494318
# std     1423.333987     2.349440    3.524589    8.294731   14.594323
# min    19973.000000  2010.000000   20.000000   38.000000    4.000000
# 25%    20990.750000  2011.000000   24.000000   70.000000   62.750000
# 50%    22268.500000  2013.500000   26.000000   77.000000   75.000000
# 75%    23576.750000  2016.000000   28.000000   80.250000   80.000000
# max    24654.000000  2017.000000   37.000000   82.000000   82.000000
#
#                 MP         PER         TS%        3PAr         FTr  ...  \
# count   176.000000  176.000000  176.000000  176.000000  176.000000  ...
# mean   2526.090909   19.545455    0.548557    0.273722    0.320773  ...
# std     363.491863    4.342992    0.042653    0.122114    0.108033  ...
# ...

# %%
data_ast_grouped_by_year = data_ast.groupby(['Year'])

# %%
type(data_ast_grouped_by_year['AST'])
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
data_ast_filtered = data_ast.filter(items = ['AST', 'Player', 'MP', 'STL'])

# %%
type(data_ast_filtered)
# Out:
# pandas.core.frame.DataFrame

# %%
data_ast_filtered.describe()
# Out:
#               AST           MP         STL
# count  176.000000   176.000000  176.000000
# mean   533.181818  2526.090909  106.607955
# std    118.977793   363.491863   34.865288
# min    400.000000  1423.000000   38.000000
# 25%    444.250000  2251.500000   80.500000
# 50%    498.500000  2569.000000  103.500000
# 75%    598.000000  2814.750000  134.000000
# max    906.000000  3227.000000  191.000000

# %%
data_ast_filtered.boxplot(column='AST')

# %%
data_ast_filtered.corr()
# Out:
#           AST        MP       STL
# AST  1.000000  0.301356  0.377047
# MP   0.301356  1.000000  0.477707
# STL  0.377047  0.477707  1.000000

# %%
import seaborn as sns

# %%
data_ast_filtered = data_ast_filtered.corr()

# %%
sns.heatmap(data_ast_filtered)

# %%
'''
sns.heatmap(filtered_data_2016.corr(), robust=True, linewidths=2, cbar = True, square = True, 
            xticklabels=True, yticklabels= True, annot = True)
'''

sns.heatmap(data_ast_filtered, robust=True, linewidths=2, cbar = True, square=True, xticklabels=True, yticklabels=True,
           annot = True)

# %%
sns.boxplot(data=data['AST'], orient='h', color = 'g', )

# %%
data.sort_values(by='Player')
# Out:
#        Unnamed: 0    Year         Player  Pos   Age   Tm     G    GS      MP  \
# 9688         9688  1990.0     A.C. Green   PF  26.0  LAL  82.0  82.0  2709.0
# 11060       11060  1993.0     A.C. Green   PF  29.0  LAL  82.0  55.0  2819.0
# 14648       14648  2000.0     A.C. Green   PF  36.0  LAL  82.0  82.0  1929.0
# 14139       14139  1999.0     A.C. Green   PF  35.0  DAL  50.0  35.0   924.0
# 13600       13600  1998.0     A.C. Green   PF  34.0  DAL  82.0  68.0  2649.0
# 8035         8035  1986.0     A.C. Green   PF  22.0  LAL  82.0   1.0  1542.0
# 10617       10617  1992.0     A.C. Green   PF  28.0  LAL  82.0  53.0  2902.0
# 13035       13035  1997.0     A.C. Green   PF  33.0  PHO  27.0  19.0   548.0
# 10166       10166  1991.0     A.C. Green   PF  27.0  LAL  82.0  21.0  2164.0
# 13034       13034  1997.0     A.C. Green   PF  33.0  TOT  83.0  73.0  2492.0
# 8420         8420  1987.0     A.C. Green   PF  23.0  LAL  79.0  72.0  2240.0
# ...
